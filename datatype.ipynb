# %% [markdown]
# Datatypes in python

# %%
##integer example
age=35
type(age)
# Out:
# int

# %%
##floating point datatype
height=5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
##string
name="Ashvija"
print(name)
print(type(name))
# Out:
# Ashvija
# <class 'str'>

# %%
#boolean
is_true=True
type(is_true)
# Out:
# bool

# %%
a=10
b=10
a==b
type(a==b)
# Out:
# bool

# %%
##common errors
result="hello"
print(result)
# Out:
# hello

# %%
##common errors
result="hello" +str("5")
print(result)
# Out:
# hello5

# %%
str="hello"
